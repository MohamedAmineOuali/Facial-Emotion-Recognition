# %%
import tensorflow as tf
import keras
import numpy as np
import os
import h5py
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
from keras.layers import *
from tensorflow.python import debug as tf_debug
import cv2
# keras.backend.set_session(tf_debug.TensorBoardDebugWrapperSession(tf.Session(),"linux-sdq4:6064",send_traceback_and_source_code=False))
from keras.layers.convolutional import Convolution2D, MaxPooling2D, ZeroPadding2D
# Out:
# /usr/lib64/python3.4/importlib/_bootstrap.py:321: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   return f(*args, **kwds)
# Using TensorFlow backend.

# %%
DATA_PATH = '../dataset/sequences/train.h5'

f = h5py.File(DATA_PATH, 'r')

X_train = np.copy(f['data'])
y_train = np.copy(f['labels'])

del f

# %%
X_train.shape
# Out:
# (720, 5, 100, 100)

# %%
def show_images(images, cols = 1, titles = None):
    """Display a list of images in a single figure with matplotlib.
    
    Parameters
    ---------
    images: List of np.arrays compatible with plt.imshow.
    
    cols (Default = 1): Number of columns in figure (number of rows is 
                        set to np.ceil(n_images/float(cols))).
    
    titles: List of titles corresponding to each image. Must have
            the same length as titles.
    """
    assert((titles is None)or (len(images) == len(titles)))
    n_images = len(images)
    if titles is None: titles = ['Image (%d)' % i for i in range(1,n_images + 1)]
    fig = plt.figure()
    for n, (image, title) in enumerate(zip(images, titles)):
        a = fig.add_subplot(cols, np.ceil(n_images/float(cols)), n + 1)
        if image.ndim == 2:
            plt.gray()
        plt.imshow(image)
        a.set_title(title)
    fig.set_size_inches(np.array(fig.get_size_inches()) * n_images)
    plt.show()

images=[]
for i,k in enumerate(y_train):
    if(k==2):
        kk=X_train[i,4,:,:]
        kk=cv2.resize(kk, (48, 48))
        images.append(kk.astype(int))

# %%
plt.imshow(images[6])
plt.show()

# %%
show_images(images[1:],16)

# %%
size=[]
for i in range(0,6):
    size.append(np.count_nonzero(y_train==i))
size
# Out:
# [120, 120, 120, 120, 120, 120]
